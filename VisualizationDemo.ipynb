# %%
from LoRA import *

average_result = matrix_approximation_experiment(matrix_sizes=[(30, 30)],
                                                 distributions=['uniform',
                                                                'normal',
                                                                'exponential'],
                                                 num_iterations=15, k=15, c=15,
                                                 eps=0.9)

generate_results_table(average_result)
# Out:
# ...
# Matrix Size: 100%|██████████| 1/1 [00:15<00:00, 15.26s/it]
#         Size Distribution                 Method  Avg Frobenius Error Ratio  \
# 0   (30, 30)      uniform      near_optimal_CSSP                   1.501033
# 1   (30, 30)      uniform           adaptive_CUR                   1.080446
# 2   (30, 30)      uniform         randomized_svd                   1.534507
# 3   (30, 30)      uniform  randomized_projection                   1.024561
# 4   (30, 30)       normal      near_optimal_CSSP                   1.500737
# 5   (30, 30)       normal           adaptive_CUR                   1.397570
# 6   (30, 30)       normal         randomized_svd                   1.539819
# 7   (30, 30)       normal  randomized_projection                   1.030822
# 8   (30, 30)  exponential      near_optimal_CSSP                   1.567713
# 9   (30, 30)  exponential           adaptive_CUR                   1.227876
# 10  (30, 30)  exponential         randomized_svd                   1.648526
# ...

# %%
plot_results_graph(average_result)
